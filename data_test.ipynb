# %%
import numpy as np
import matplotlib.pyplot as ply
import pandas as pd
import seaborn as sns

# %%
lines = []
with open("Dane\wind_5min_shifted_all_1.lst", "r") as file:
  for line in file:
    lines.append(line.split())

# %%
headers = []
with open("Dane\wind_5min_shifted_all_1.fmt", "r") as file:
  for header in file:
    headers.append(header.split()[1:2])

# %%
print(lines[0:5])
# Out:
# [['2017', '1', '0', '0', '2806', '7.31', '-5.90', '-0.82', '-3.74', '0.17', '-3.82', '1414', '0.63', '1.38', '546.5', '-544.9', '40.7', '-9.6', '7.81', '164969.', '197.07', '54.59', '-11.40', '11.07', '-1.45', '0.19'], ['2017', '1', '0', '5', '2306', '6.99', '-5.92', '-0.97', '-2.92', '-0.19', '-3.07', '208', '0.15', '1.15', '550.9', '-548.5', '49.5', '-7.1', '7.52', '166973.', '197.07', '54.65', '-11.40', '11.24', '-1.62', '0.17'], ['2017', '1', '0', '10', '2111', '7.09', '-5.86', '-2.06', '-3.06', '-1.21', '-3.48', '1064', '0.59', '1.01', '552.1', '-550.2', '45.3', '-9.2', '7.16', '131817.', '197.07', '54.62', '-11.40', '11.19', '-1.54', '0.15'], ['2017', '1', '0', '15', '2196', '7.04', '-6.16', '0.27', '-2.38', '0.87', '-2.23', '557', '0.27', '1.33', '550.1', '-548.9', '30.3', '-13.4', '7.07', '141558.', '197.07', '54.64', '-11.40', '11.40', '-1.28', '0.25'], ['2017', '1', '0', '20', '1809', '7.05', '-6.25', '-0.06', '-2.17', '0.50', '-2.12', '454', '0.24', '1.33', '544.8', '-543.1', '38.6', '-10.9', '6.88', '134118.', '197.07', '54.68', '-11.40', '11.47', '-1.50', '0.23']]

# %%
data_frame = pd.DataFrame(lines, columns=["Year",
                                            "Day",
                                            "Hour",
                                            "Minute",
                                            "Timeshift",
                                            "Scalar_B",
                                            "BX(GSE)",
                                            "BY(GSE)",
                                            "BZ(GSE)",
                                            "BY(GSM)",
                                            "BZ(GSM)" ,
                                            "RMS(timeshift)",
                                            "RMS(Phase_frnt_nrml)",
                                            "RMS(Field_vector)",
                                            "Flow_speed",
                                            "Vx",
                                            "Vy",
                                            "Vz",
                                            "Proton_Density",
                                            "Temperature",
                                            "X(s/c)",
                                            "Y(s/c)",
                                            "Z(s/c)",
                                            "X(target)",
                                            "Y(target)",
                                            "Z(target)"], dtype=float)

# %%
data_frame.head()
# Out:
#      Year  Day  Hour  Minute  Timeshift  Scalar_B  BX(GSE)  BY(GSE)  BZ(GSE)  \
# 0  2017.0  1.0   0.0     0.0     2806.0      7.31    -5.90    -0.82    -3.74
# 1  2017.0  1.0   0.0     5.0     2306.0      6.99    -5.92    -0.97    -2.92
# 2  2017.0  1.0   0.0    10.0     2111.0      7.09    -5.86    -2.06    -3.06
# 3  2017.0  1.0   0.0    15.0     2196.0      7.04    -6.16     0.27    -2.38
# 4  2017.0  1.0   0.0    20.0     1809.0      7.05    -6.25    -0.06    -2.17
#
#    BY(GSM)  ...    Vy    Vz  Proton_Density  Temperature  X(s/c)  Y(s/c)  \
# 0     0.17  ...  40.7  -9.6            7.81     164969.0  197.07   54.59
# 1    -0.19  ...  49.5  -7.1            7.52     166973.0  197.07   54.65
# 2    -1.21  ...  45.3  -9.2            7.16     131817.0  197.07   54.62
# 3     0.87  ...  30.3 -13.4            7.07     141558.0  197.07   54.64
# 4     0.50  ...  38.6 -10.9            6.88     134118.0  197.07   54.68
#
#    Z(s/c)  X(target)  Y(target)  Z(target)
# 0   -11.4      11.07      -1.45       0.19
# 1   -11.4      11.24      -1.62       0.17
# 2   -11.4      11.19      -1.54       0.15
# 3   -11.4      11.40      -1.28       0.25
# 4   -11.4      11.47      -1.50       0.23
#
# [5 rows x 26 columns]

# %%
data_frame.dtypes
# Out:
# Year                    float64
# Day                     float64
# Hour                    float64
# Minute                  float64
# Timeshift               float64
# Scalar_B                float64
# BX(GSE)                 float64
# BY(GSE)                 float64
# BZ(GSE)                 float64
# BY(GSM)                 float64
# BZ(GSM)                 float64
# RMS(timeshift)          float64
# RMS(Phase_frnt_nrml)    float64
# RMS(Field_vector)       float64
# Flow_speed              float64
# Vx                      float64
# Vy                      float64
# Vz                      float64
# Proton_Density          float64
# Temperature             float64
# X(s/c)                  float64
# Y(s/c)                  float64
# Z(s/c)                  float64
# X(target)               float64
# Y(target)               float64
# Z(target)               float64
# dtype: object

# %%
data = np.array(lines)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(data_frame, annot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Hackaton\HackatonNASA\data_prepare.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/e%3A/Hackaton/HackatonNASA/data_prepare.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> sns.set(rc={'figure.figsize':(11.7,8.27)})
# ----> <a href='vscode-notebook-cell:/e%3A/Hackaton/HackatonNASA/data_prepare.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> sns.heatmap(data_frame, annot=True)
#
# File d:\venvs\p39_sklearn\lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File d:\venvs\p39_sklearn\lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File d:\venvs\p39_sklearn\lib\site-packages\seaborn\matrix.py:263, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
# --> 263 ax.text(x, y, annotation, **text_kwargs)
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\axes\_axes.py:702, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     700 t = mtext.Text(x, y, text=s, **effective_kwargs)
#     701 if t.get_clip_path() is None:
# --> 702     t.set_clip_path(self.patch)
#     703 self._add_text(t)
#     704 return t
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\text.py:593, in Text.set_clip_path(self, path, transform)
#     591 def set_clip_path(self, path, transform=None):
#     592     # docstring inherited.
# --> 593     super().set_clip_path(path, transform)
#     594     self._update_clip_properties()
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\artist.py:803, in Artist.set_clip_path(self, path, transform)
#     800 if transform is None:
#     801     if isinstance(path, Rectangle):
#     802         self.clipbox = TransformedBbox(Bbox.unit(),
# --> 803                                        path.get_transform())
#     804         self._clippath = None
#     805         success = True
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\patches.py:261, in Patch.get_transform(self)
#     259 def get_transform(self):
#     260     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 261     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\patches.py:751, in Rectangle.get_patch_transform(self)
#     746 def get_patch_transform(self):
#     747     # Note: This cannot be called until after this has been added to
#     748     # an Axes, otherwise unit conversion will fail. This makes it very
#     749     # important to call the accessor method and not directly access the
#     750     # transformation member variable.
# --> 751     bbox = self.get_bbox()
#     752     if self.rotation_point == 'center':
#     753         width, height = bbox.x1 - bbox.x0, bbox.y1 - bbox.y0
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\patches.py:882, in Rectangle.get_bbox(self)
#     880 def get_bbox(self):
#     881     """Return the `.Bbox`."""
# --> 882     return transforms.Bbox.from_extents(*self._convert_units())
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\transforms.py:829, in Bbox.from_extents(minpos, *args)
#     813 @staticmethod
#     814 def from_extents(*args, minpos=None):
#     815     """
#     816     Create a new Bbox from *left*, *bottom*, *right* and *top*.
#     817
#    (...)
#     827         scales where negative bounds result in floating point errors.
#     828     """
# --> 829     bbox = Bbox(np.reshape(args, (2, 2)))
#     830     if minpos is not None:
#     831         bbox._minpos[:] = minpos
#
# File d:\venvs\p39_sklearn\lib\site-packages\matplotlib\transforms.py:771, in Bbox.__init__(self, points, **kwargs)
#     768     raise ValueError('Bbox points must be of the form '
#     769                      '"[[x0, y0], [x1, y1]]".')
#     770 self._points = points
# --> 771 self._minpos = _default_minpos.copy()
#     772 self._ignore = True
#     773 # it is helpful in some contexts to know if the bbox is a
#     774 # default or has been mutated; we store the orig points to
#     775 # support the mutated methods
#
# KeyboardInterrupt:

# %% [markdown]
# Day
# Hour
# Minute
# Timeshift
# Scalar_B
# BX(GSE)
# BY(GSE)
# BZ(GSE)
# BY(GSM)
# BZ(GSM)
# RMS(timeshift)
# RMS(Phase_frnt_nrml)
# RMS(Field_vector)
# Flow_speed
# Vx
# Vy
# Vz
# Proton_Density
# Temperature
# X(s/c)
# Y(s/c)
# Z(s/c)
# X(target)
# Y(target)
# Z(target)
